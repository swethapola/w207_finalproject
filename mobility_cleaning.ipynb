# %%
import pandas as pd
import numpy as np
import datetime
import os

# %%
cwd = os.getcwd() + '/raw_data/'
clean_dir = os.getcwd() + '/clean_data/'


mobility = pd.read_csv(cwd+'2020_US_Region_Mobility_Report.csv') #read in data
mobility.head()
max(mobility['date'])
# Out:
# '2020-11-29'

# %%
mobility['date'] = pd.to_datetime(mobility['date']) #convert str object to datetime
date_after = pd.to_datetime('2020-03-20') #this is where our twitter data begins
date_before = pd.to_datetime('2020-12-01') #this is where our twitter data ends
mobility = mobility[mobility['date'] >= date_after]
mobility = mobility[mobility['date'] <= date_before]
mobility = mobility.rename(columns={"retail_and_recreation_percent_change_from_baseline": "retail_rec", 
                                    "grocery_and_pharmacy_percent_change_from_baseline": "groc_pharm",
                                   "parks_percent_change_from_baseline": "parks",
                                   "transit_stations_percent_change_from_baseline": "transit",
                                   "workplaces_percent_change_from_baseline": "workplaces",
                                   "residential_percent_change_from_baseline": "residential"})
mobility.head()
# Out:
#    country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 34                  US  United States          NaN          NaN         NaN
# 35                  US  United States          NaN          NaN         NaN
# 36                  US  United States          NaN          NaN         NaN
# 37                  US  United States          NaN          NaN         NaN
# 38                  US  United States          NaN          NaN         NaN
#
#    iso_3166_2_code  census_fips_code       date  retail_rec  groc_pharm  \
# 34             NaN               NaN 2020-03-20       -32.0         5.0
# 35             NaN               NaN 2020-03-21       -40.0        -2.0
# 36             NaN               NaN 2020-03-22       -44.0       -13.0
# 37             NaN               NaN 2020-03-23       -38.0       -10.0
# 38             NaN               NaN 2020-03-24       -39.0       -12.0
#
#     parks  transit  workplaces  residential
# 34   -2.0    -37.0       -36.0         16.0
# 35   -3.0    -36.0       -24.0         12.0
# 36  -12.0    -44.0       -31.0         11.0
# 37  -23.0    -47.0       -41.0         17.0
# 38  -10.0    -46.0       -45.0         19.0

# %%
fl = mobility[mobility['sub_region_1'] == 'Florida']
fl = fl[fl['sub_region_2'].notna()]

# %%
fl.head()
# Out:
#       country_region_code country_region sub_region_1    sub_region_2  \
# 76022                  US  United States      Florida  Alachua County
# 76023                  US  United States      Florida  Alachua County
# 76024                  US  United States      Florida  Alachua County
# 76025                  US  United States      Florida  Alachua County
# 76026                  US  United States      Florida  Alachua County
#
#        metro_area iso_3166_2_code  census_fips_code       date  retail_rec  \
# 76022         NaN             NaN           12001.0 2020-03-20       -30.0
# 76023         NaN             NaN           12001.0 2020-03-21       -42.0
# 76024         NaN             NaN           12001.0 2020-03-22       -45.0
# 76025         NaN             NaN           12001.0 2020-03-23       -36.0
# 76026         NaN             NaN           12001.0 2020-03-24       -46.0
#
#        groc_pharm  parks  transit  workplaces  residential
# 76022         3.0  -17.0    -29.0       -33.0         16.0
# 76023        -2.0  -31.0    -26.0       -20.0         10.0
# 76024       -11.0  -18.0    -35.0       -29.0         10.0
# 76025        -3.0  -21.0    -35.0       -41.0         16.0
# 76026       -20.0  -29.0    -40.0       -46.0         20.0

# %%
fl.to_csv(clean_dir+'florida_mobility.csv') #read in data
